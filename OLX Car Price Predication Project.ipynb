# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('olx_car_data_csv.csv')
df.head()
# Out:
#     Brand Condition    Fuel  KMs Driven        Model    Price Registered City  \
# 0  Toyota      Used  Diesel         1.0        Prado  2100000         Karachi
# 1  Suzuki      Used  Petrol    100000.0        Bolan   380000         Karachi
# 2  Suzuki      Used     CNG     12345.0        Bolan   340000         Karachi
# 3  Suzuki      Used  Petrol     94000.0         Alto   535000         Karachi
# 4  Toyota      Used  Petrol    100000.0  Corolla XLI  1430000         Karachi
#
#   Transaction Type    Year
# 0             Cash  1997.0
# 1             Cash  2006.0
# 2             Cash  1998.0
# 3             Cash  2010.0
# 4             Cash  2013.0

# %%
df.tail()
# Out:
#               Brand Condition    Fuel  KMs Driven        Model    Price  \
# 24968        Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969      Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24970  Other Brands      Used     CNG    158715.0        Other   180000
# 24971        Suzuki      Used  Petrol         1.0         Alto   470000
# 24972        Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 24968          Lahore             Cash  2001.0
# 24969         Karachi             Cash  2004.0
# 24970             NaN             Cash  2000.0
# 24971      Rawalpindi             Cash  2003.0
# 24972          Lahore             Cash  2017.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24973 entries, 0 to 24972
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             22836 non-null  object
#  1   Condition         22837 non-null  object
#  2   Fuel              22528 non-null  object
#  3   KMs Driven        22687 non-null  float64
#  4   Model             22525 non-null  object
#  5   Price             24973 non-null  int64
#  6   Registered City   20337 non-null  object
#  7   Transaction Type  22528 non-null  object
#  8   Year              22689 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#          KMs Driven         Price          Year
# count  2.268700e+04  2.497300e+04  22689.000000
# mean   1.278112e+05  9.128953e+05   2005.901626
# std    5.996726e+05  1.537134e+06      9.563804
# min    1.000000e+00  5.000000e+04   1915.000000
# 25%    1.600000e+04  3.800000e+05   2002.000000
# 50%    6.651000e+04  6.500000e+05   2008.000000
# 75%    1.000000e+05  1.145000e+06   2013.000000
# max    1.000000e+07  8.765432e+07   2020.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24973 entries, 0 to 24972
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             22836 non-null  object
#  1   Condition         22837 non-null  object
#  2   Fuel              22528 non-null  object
#  3   KMs Driven        22687 non-null  float64
#  4   Model             22525 non-null  object
#  5   Price             24973 non-null  int64
#  6   Registered City   20337 non-null  object
#  7   Transaction Type  22528 non-null  object
#  8   Year              22689 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
df.shape
# Out:
# (24973, 9)

# %%
# fill the missing values for numerical terms - mean
df['KMs Driven']=df['KMs Driven'].fillna(df['KMs Driven'].mean())

df['Year']=df['Year'].fillna(df['Year'].mean())

# %%
df=df[~df['Fuel'].isna()]

# %%
df=df[~df['Brand'].isna()]

# %%
df=df[~df['Condition'].isna()]

# %%
df=df[~df['Model'].isna()]

# %%
df=df[~df['Registered City'].isna()]

# %%
df=df[~df['Transaction Type'].isna()]

# %%
df.shape
# Out:
# (20334, 9)

# %%
df
# Out:
#           Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0        Toyota      Used  Diesel         1.0        Prado  2100000
# 1        Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2        Suzuki      Used     CNG     12345.0        Bolan   340000
# 3        Suzuki      Used  Petrol     94000.0         Alto   535000
# 4        Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...         ...       ...     ...         ...          ...      ...
# 24966    Toyota      Used  Petrol     76190.0       Avanza  1175000
# 24968    Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969  Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24971    Suzuki      Used  Petrol         1.0         Alto   470000
# 24972    Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# 1             Karachi             Cash  2006.0
# ...

# %%
df=df.reset_index(drop=True)

# %% [markdown]
# # Cleaned Data

# %%
df
# Out:
#           Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0        Toyota      Used  Diesel         1.0        Prado  2100000
# 1        Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2        Suzuki      Used     CNG     12345.0        Bolan   340000
# 3        Suzuki      Used  Petrol     94000.0         Alto   535000
# 4        Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...         ...       ...     ...         ...          ...      ...
# 20329    Toyota      Used  Petrol     76190.0       Avanza  1175000
# 20330    Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 20331  Daihatsu       New  Petrol     10000.0        Cuore   390000
# 20332    Suzuki      Used  Petrol         1.0         Alto   470000
# 20333    Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# 1             Karachi             Cash  2006.0
# ...

# %%
df.to_csv('Cleaned_OLX_Car_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20334 entries, 0 to 20333
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             20334 non-null  object
#  1   Condition         20334 non-null  object
#  2   Fuel              20334 non-null  object
#  3   KMs Driven        20334 non-null  float64
#  4   Model             20334 non-null  object
#  5   Price             20334 non-null  int64
#  6   Registered City   20334 non-null  object
#  7   Transaction Type  20334 non-null  object
#  8   Year              20334 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.4+ MB

# %%
df.describe(include='all')
# Out:
#          Brand Condition    Fuel    KMs Driven       Model         Price  \
# count    20334     20334   20334  2.033400e+04       20334  2.033400e+04
# unique      23         2       5           NaN         296           NaN
# top     Suzuki      Used  Petrol           NaN  Cultus VXR           NaN
# freq      8891     16927   12759           NaN        1713           NaN
# mean       NaN       NaN     NaN  1.351206e+05         NaN  8.692863e+05
# std        NaN       NaN     NaN  6.278440e+05         NaN  1.527317e+06
# min        NaN       NaN     NaN  1.000000e+00         NaN  5.000000e+04
# 25%        NaN       NaN     NaN  1.918125e+04         NaN  3.700000e+05
# 50%        NaN       NaN     NaN  7.000000e+04         NaN  6.250000e+05
# 75%        NaN       NaN     NaN  1.000000e+05         NaN  1.080000e+06
# max        NaN       NaN     NaN  1.000000e+07         NaN  8.765432e+07
#
#        Registered City Transaction Type          Year
# ...

# %% [markdown]
# # Checking relationship of Company with Price

# %%
df['Model'].unique()
# Out:
# array(['Prado', 'Bolan', 'Alto', 'Corolla XLI', 'Corrolla Altis',
#        'Cultus VXL', 'Civic VTi', 'Khyber', 'Liana', 'Passo',
#        'Civic Prosmetic', 'Civic EXi', 'Charade', 'Pajero Mini',
#        'Margalla', 'City IVTEC', 'Classic', 'Other', 'Corolla GLI',
#        'Cultus VXR', 'Dayz Highway Star', 'Mehran VX', 'Vitz',
#        'Mehran VXR', 'Carry', 'Cultus VX', 'Baleno', 'Mira',
#        'Civic VTi Oriel Prosmatec', 'Cuore', 'Corolla 2.0 D',
#        'Corolla XE', 'Surf', 'FX', 'City IDSI', 'Premio', 'Sprinter',
#        '3 Series', 'Hilux', 'Lancer', 'Swift', 'Estima', 'Vamos',
#        'Starlet', 'Prius', 'Joy', '323', 'Racer', 'Sunny', 'Accord',
#        'Zest', 'AD Van', 'APV', 'March', 'Pride', 'Sportage',
#        'Terios Kid', 'Santro', 'Fit', 'V2', 'City Aspire',
#        'Civic VTi Oriel', 'BR-V', 'Kei', 'Probox', 'Hijet', '86', 'Yaris',
#        'Aygo', 'Rush', 'Dayz', 'Fortuner', 'Every', 'Camry', 'Aqua',
# ...

# %%
#plt.subplots(figsize=(45,57))
#ax=sns.boxplot(x='Model',y='Price',data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
#plt.show()

# %% [markdown]
# # Checking relationship of Year with Price

# %%
#plt.subplots(figsize=(40,40))
#ax=sns.swarmplot(x='Year',y='Price',data=df)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
#plt.show()

# %% [markdown]
# # Checking relationship of kms_driven with Price

# %%
#sns.relplot(x='KMs Driven',y='Price',data=df,height=8,aspect=1.5)

# %% [markdown]
# # Checking relationship of Fuel Type with Price

# %%
#plt.subplots(figsize=(20,10))
#sns.boxplot(x='Fuel',y='Price',data=df)

# %% [markdown]
# # Relationship of Price with FuelType, Year and Company mixed

# %%
#ax=sns.relplot(x='Model',y='Price',data=df,hue='Fuel',size='Year',height=20,aspect=2)
#ax.set_xticklabels(rotation=40,ha='right')

# %%
df
# Out:
#           Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0        Toyota      Used  Diesel         1.0        Prado  2100000
# 1        Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2        Suzuki      Used     CNG     12345.0        Bolan   340000
# 3        Suzuki      Used  Petrol     94000.0         Alto   535000
# 4        Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...         ...       ...     ...         ...          ...      ...
# 20329    Toyota      Used  Petrol     76190.0       Avanza  1175000
# 20330    Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 20331  Daihatsu       New  Petrol     10000.0        Cuore   390000
# 20332    Suzuki      Used  Petrol         1.0         Alto   470000
# 20333    Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# 1             Karachi             Cash  2006.0
# ...

# %%
#df=pd.DataFrame('Year')
df['Year']=df['Year'].astype(int)

# %%
df['KMs Driven']=df['KMs Driven'].astype(int)

# %%
df['Price']=df['Price'].astype(int)

# %%
df['Brand']=df['Brand'].astype(str)

# %%
df['Condition']=df['Condition'].astype(str)

# %%
df['Fuel']=df['Fuel'].astype(str)

# %%
df['Model']=df['Model'].astype(str)

# %%
df['Registered City']=df['Registered City'].astype(str)

# %%
df['Transaction Type']=df['Transaction Type'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20334 entries, 0 to 20333
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             20334 non-null  object
#  1   Condition         20334 non-null  object
#  2   Fuel              20334 non-null  object
#  3   KMs Driven        20334 non-null  int32
#  4   Model             20334 non-null  object
#  5   Price             20334 non-null  int32
#  6   Registered City   20334 non-null  object
#  7   Transaction Type  20334 non-null  object
#  8   Year              20334 non-null  int32
# dtypes: int32(3), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# # Extracting Training Data

# %%
X=df[['Brand','Condition','Fuel','KMs Driven','Model','Registered City','Transaction Type','Year']]
y=df['Price']

# %%
X
# Out:
#           Brand Condition    Fuel  KMs Driven        Model Registered City  \
# 0        Toyota      Used  Diesel           1        Prado         Karachi
# 1        Suzuki      Used  Petrol      100000        Bolan         Karachi
# 2        Suzuki      Used     CNG       12345        Bolan         Karachi
# 3        Suzuki      Used  Petrol       94000         Alto         Karachi
# 4        Toyota      Used  Petrol      100000  Corolla XLI         Karachi
# ...         ...       ...     ...         ...          ...             ...
# 20329    Toyota      Used  Petrol       76190       Avanza          Lahore
# 20330    Toyota      Used     CNG      200000   Corolla XE          Lahore
# 20331  Daihatsu       New  Petrol       10000        Cuore         Karachi
# 20332    Suzuki      Used  Petrol           1         Alto      Rawalpindi
# 20333    Toyota      Used  Petrol       48500  Corolla GLI          Lahore
#
#       Transaction Type  Year
# 0                 Cash  1997
# ...

# %%
X.shape
# Out:
# (20334, 8)

# %%
y.shape
# Out:
# (20334,)

# %% [markdown]
# # Appling Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# # Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()

# %%
one_hot=ohe.fit(X[['Brand','Condition','Fuel','Model','Registered City','Transaction Type']])

# %%
df
# Out:
#           Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0        Toyota      Used  Diesel           1        Prado  2100000
# 1        Suzuki      Used  Petrol      100000        Bolan   380000
# 2        Suzuki      Used     CNG       12345        Bolan   340000
# 3        Suzuki      Used  Petrol       94000         Alto   535000
# 4        Toyota      Used  Petrol      100000  Corolla XLI  1430000
# ...         ...       ...     ...         ...          ...      ...
# 20329    Toyota      Used  Petrol       76190       Avanza  1175000
# 20330    Toyota      Used     CNG      200000   Corolla XE  1070000
# 20331  Daihatsu       New  Petrol       10000        Cuore   390000
# 20332    Suzuki      Used  Petrol           1         Alto   470000
# 20333    Toyota      Used  Petrol       48500  Corolla GLI  2050000
#
#       Registered City Transaction Type  Year
# 0             Karachi             Cash  1997
# 1             Karachi             Cash  2006
# ...

# %% [markdown]
# # Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Brand','Condition','Fuel','Model','Registered City','Transaction Type']),
                                    remainder='passthrough')
X=column_trans.fit_transform(X)

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['Audi', 'BMW', 'Changan', 'Chevrolet', 'Classic & Antiques',
#        'Daewoo', 'Daihatsu', 'FAW', 'Honda', 'Hyundai', 'KIA',
#        'Land Rover', 'Lexus', 'Mazda', 'Mercedes', 'Mitsubishi', 'Nissan',
#        'Other Brands', 'Porsche', 'Range Rover', 'Subaru', 'Suzuki',
#        'Toyota'], dtype=object),...
#        'Mandi Bahauddin', 'Mardan', 'Mirpur', 'Multan', 'Muzaffarabad',
#        'Muzaffargarh', 'Nawabshah', 'Nowshera', 'Okara', 'Pakpattan',
#        'Peshawar', 'Quetta', 'Rahimyar Khan', 'Rawalpindi', 'Sahiwal',
#        'Sargodha', 'Sheikhupura', 'Sialkot', 'Sukkar', 'Sukkur', 'Swabi',
#        'Swat', 'Tank', 'Vehari', 'Wah'], dtype=object),
#                                                            array(['Cash', 'Installment/Leasing'], dtype=object)]),
# ...

# %% [markdown]
# # Linear Reg Model

# %%
lr=LinearRegression()

# %% [markdown]
# # Making a pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# # Fitting the model

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi', 'BMW', 'Changan', 'Chevrolet', 'Classic & Antiques',
#        'Daewoo', 'Daihatsu', 'FAW', 'Honda', 'Hyundai', 'KIA',
#        'Land Rover', 'Lexus', 'Mazda', 'Mercedes', 'Mitsubishi', 'Nissan',
#        'Other Brands', 'Porsche', 'Range Rover', 'Suba...
#        'Muzaffargarh', 'Nawabshah', 'Nowshera', 'Okara', 'Pakpattan',
#        'Peshawar', 'Quetta', 'Rahimyar Khan', 'Rawalpindi', 'Sahiwal',
#        'Sargodha', 'Sheikhupura', 'Sialkot', 'Sukkar', 'Sukkur', 'Swabi',
#        'Swat', 'Tank', 'Vehari', 'Wah'], dtype=object),
#                                                                             array(['Cash', 'Installment/Leasing'], dtype=object)]),
# ...

# %%
y_pred=pipe.predict(X_test)

# %% [markdown]
# # Creating R2 Score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.47230416981054557
